# %% [markdown]
# 7. Написать программу, доказывающую или проверяющую, что для множества натуральных чисел выполняется равенство: 1+2+...+n = n(n+1)/2, где n — любое натуральное число.

# %%
def first(n):
    if n == 1:
        return n
    elif n > 0:
        return n + first(n-1)


def second(n):
    return n * (n + 1) // 2


n = 1

while True:
    if first(n) == second(n):
        print(f'Для n={n} - True')
    else:
        print(f'Для n={n} - False')
        break
    n += 1
# Out:
# Для n=1 - True
# Для n=2 - True
# Для n=3 - True
# Для n=4 - True
# Для n=5 - True
# Для n=6 - True
# Для n=7 - True
# Для n=8 - True
# Для n=9 - True
# Для n=10 - True
# Для n=11 - True
# Для n=12 - True
# Для n=13 - True
# Для n=14 - True
# Для n=15 - True
# Для n=16 - True
# Для n=17 - True
# Для n=18 - True
# Для n=19 - True
# Для n=20 - True
# Для n=21 - True
# Для n=22 - True
# Для n=23 - True
# Для n=24 - True
# Для n=25 - True
# Для n=26 - True
# Для n=27 - True
# Для n=28 - True
# Для n=29 - True
# Для n=30 - True
# Для n=31 - True
# Для n=32 - True
# Для n=33 - True
# Для n=34 - True
# Для n=35 - True
# Для n=36 - True
# Для n=37 - True
# Для n=38 - True
# Для n=39 - True
# Для n=40 - True
# Для n=41 - True
# Для n=42 - True
# Для n=43 - True
# Для n=44 - True
# Для n=45 - True
# Для n=46 - True
# Для n=47 - True
# Для n=48 - True
# Для n=49 - True
# Для n=50 - True
# Для n=51 - True
# Для n=52 - True
# Для n=53 - True
# Для n=54 - True
# Для n=55 - True
# Для n=56 - True
# Для n=57 - True
# Для n=58 - True
# Для n=59 - True
# Для n=60 - True
# Для n=61 - True
# Для n=62 - True
# Для n=63 - True
# Для n=64 - True
# Для n=65 - True
# Для n=66 - True
# Для n=67 - True
# Для n=68 - True
# Для n=69 - True
# Для n=70 - True
# Для n=71 - True
# Для n=72 - True
# Для n=73 - True
# Для n=74 - True
# Для n=75 - True
# Для n=76 - True
# Для n=77 - True
# Для n=78 - True
# Для n=79 - True
# Для n=80 - True
# Для n=81 - True
# Для n=82 - True
# Для n=83 - True
# Для n=84 - True
# Для n=85 - True
# Для n=86 - True
# Для n=87 - True
# Для n=88 - True
# Для n=89 - True
# Для n=90 - True
# Для n=91 - True
# Для n=92 - True
# Для n=93 - True
# Для n=94 - True
# Для n=95 - True
# Для n=96 - True
# Для n=97 - True
# Для n=98 - True
# Для n=99 - True
# Для n=100 - True
# Для n=101 - True
# Для n=102 - True
# Для n=103 - True
# Для n=104 - True
# Для n=105 - True
# Для n=106 - True
# Для n=107 - True
# Для n=108 - True
# Для n=109 - True
# Для n=110 - True
# Для n=111 - True
# Для n=112 - True
# Для n=113 - True
# Для n=114 - True
# Для n=115 - True
# Для n=116 - True
# Для n=117 - True
# Для n=118 - True
# Для n=119 - True
# Для n=120 - True
# Для n=121 - True
# Для n=122 - True
# Для n=123 - True
# Для n=124 - True
# Для n=125 - True
# Для n=126 - True
# Для n=127 - True
# Для n=128 - True
# Для n=129 - True
# Для n=130 - True
# Для n=131 - True
# Для n=132 - True
# Для n=133 - True
# Для n=134 - True
# Для n=135 - True
# Для n=136 - True
# Для n=137 - True
# Для n=138 - True
# Для n=139 - True
# Для n=140 - True
# Для n=141 - True
# Для n=142 - True
# Для n=143 - True
# Для n=144 - True
# Для n=145 - True
# Для n=146 - True
# Для n=147 - True
# Для n=148 - True
# Для n=149 - True
# Для n=150 - True
# Для n=151 - True
# Для n=152 - True
# Для n=153 - True
# Для n=154 - True
# Для n=155 - True
# Для n=156 - True
# Для n=157 - True
# Для n=158 - True
# Для n=159 - True
# Для n=160 - True
# Для n=161 - True
# Для n=162 - True
# Для n=163 - True
# Для n=164 - True
# Для n=165 - True
# Для n=166 - True
# Для n=167 - True
# Для n=168 - True
# Для n=169 - True
# Для n=170 - True
# Для n=171 - True
# Для n=172 - True
# Для n=173 - True
# Для n=174 - True
# Для n=175 - True
# Для n=176 - True
# Для n=177 - True
# Для n=178 - True
# Для n=179 - True
# Для n=180 - True
# Для n=181 - True
# Для n=182 - True
# Для n=183 - True
# Для n=184 - True
# Для n=185 - True
# Для n=186 - True
# Для n=187 - True
# Для n=188 - True
# Для n=189 - True
# Для n=190 - True
# Для n=191 - True
# Для n=192 - True
# Для n=193 - True
# Для n=194 - True
# Для n=195 - True
# Для n=196 - True
# Для n=197 - True
# Для n=198 - True
# Для n=199 - True
# Для n=200 - True
# Для n=201 - True
# Для n=202 - True
# Для n=203 - True
# Для n=204 - True
# Для n=205 - True
# Для n=206 - True
# Для n=207 - True
# Для n=208 - True
# Для n=209 - True
# Для n=210 - True
# Для n=211 - True
# Для n=212 - True
# Для n=213 - True
# Для n=214 - True
# Для n=215 - True
# Для n=216 - True
# Для n=217 - True
# Для n=218 - True
# Для n=219 - True
# Для n=220 - True
# Для n=221 - True
# Для n=222 - True
# Для n=223 - True
# Для n=224 - True
# Для n=225 - True
# Для n=226 - True
# Для n=227 - True
# Для n=228 - True
# Для n=229 - True
# Для n=230 - True
# Для n=231 - True
# Для n=232 - True
# Для n=233 - True
# Для n=234 - True
# Для n=235 - True
# Для n=236 - True
# Для n=237 - True
# Для n=238 - True
# Для n=239 - True
# Для n=240 - True
# Для n=241 - True
# Для n=242 - True
# Для n=243 - True
# Для n=244 - True
# Для n=245 - True
# Для n=246 - True
# Для n=247 - True
# Для n=248 - True
# Для n=249 - True
# Для n=250 - True
# Для n=251 - True
# Для n=252 - True
# Для n=253 - True
# Для n=254 - True
# Для n=255 - True
# Для n=256 - True
# Для n=257 - True
# Для n=258 - True
# Для n=259 - True
# Для n=260 - True
# Для n=261 - True
# Для n=262 - True
# Для n=263 - True
# Для n=264 - True
# Для n=265 - True
# Для n=266 - True
# Для n=267 - True
# Для n=268 - True
# Для n=269 - True
# Для n=270 - True
# Для n=271 - True
# Для n=272 - True
# Для n=273 - True
# Для n=274 - True
# Для n=275 - True
# Для n=276 - True
# Для n=277 - True
# Для n=278 - True
# Для n=279 - True
# Для n=280 - True
# Для n=281 - True
# Для n=282 - True
# Для n=283 - True
# Для n=284 - True
# Для n=285 - True
# Для n=286 - True
# Для n=287 - True
# Для n=288 - True
# Для n=289 - True
# Для n=290 - True
# Для n=291 - True
# Для n=292 - True
# Для n=293 - True
# Для n=294 - True
# Для n=295 - True
# Для n=296 - True
# Для n=297 - True
# Для n=298 - True
# Для n=299 - True
# Для n=300 - True
# Для n=301 - True
# Для n=302 - True
# Для n=303 - True
# Для n=304 - True
# Для n=305 - True
# Для n=306 - True
# Для n=307 - True
# Для n=308 - True
# Для n=309 - True
# Для n=310 - True
# Для n=311 - True
# Для n=312 - True
# Для n=313 - True
# Для n=314 - True
# Для n=315 - True
# Для n=316 - True
# Для n=317 - True
# Для n=318 - True
# Для n=319 - True
# Для n=320 - True
# Для n=321 - True
# Для n=322 - True
# Для n=323 - True
# Для n=324 - True
# Для n=325 - True
# Для n=326 - True
# Для n=327 - True
# Для n=328 - True
# Для n=329 - True
# Для n=330 - True
# Для n=331 - True
# Для n=332 - True
# Для n=333 - True
# Для n=334 - True
# Для n=335 - True
# Для n=336 - True
# Для n=337 - True
# Для n=338 - True
# Для n=339 - True
# Для n=340 - True
# Для n=341 - True
# Для n=342 - True
# Для n=343 - True
# Для n=344 - True
# Для n=345 - True
# Для n=346 - True
# Для n=347 - True
# Для n=348 - True
# Для n=349 - True
# Для n=350 - True
# Для n=351 - True
# Для n=352 - True
# Для n=353 - True
# Для n=354 - True
# Для n=355 - True
# Для n=356 - True
# Для n=357 - True
# Для n=358 - True
# Для n=359 - True
# Для n=360 - True
# Для n=361 - True
# Для n=362 - True
# Для n=363 - True
# Для n=364 - True
# Для n=365 - True
# Для n=366 - True
# Для n=367 - True
# Для n=368 - True
# Для n=369 - True
# Для n=370 - True
# Для n=371 - True
# Для n=372 - True
# Для n=373 - True
# Для n=374 - True
# Для n=375 - True
# Для n=376 - True
# Для n=377 - True
# Для n=378 - True
# Для n=379 - True
# Для n=380 - True
# Для n=381 - True
# Для n=382 - True
# Для n=383 - True
# Для n=384 - True
# Для n=385 - True
# Для n=386 - True
# Для n=387 - True
# Для n=388 - True
# Для n=389 - True
# Для n=390 - True
# Для n=391 - True
# Для n=392 - True
# Для n=393 - True
# Для n=394 - True
# Для n=395 - True
# Для n=396 - True
# Для n=397 - True
# Для n=398 - True
# Для n=399 - True
# Для n=400 - True
# Для n=401 - True
# Для n=402 - True
# Для n=403 - True
# Для n=404 - True
# Для n=405 - True
# Для n=406 - True
# Для n=407 - True
# Для n=408 - True
# Для n=409 - True
# Для n=410 - True
# Для n=411 - True
# Для n=412 - True
# Для n=413 - True
# Для n=414 - True
# Для n=415 - True
# Для n=416 - True
# Для n=417 - True
# Для n=418 - True
# Для n=419 - True
# Для n=420 - True
# Для n=421 - True
# Для n=422 - True
# Для n=423 - True
# Для n=424 - True
# Для n=425 - True
# Для n=426 - True
# Для n=427 - True
# Для n=428 - True
# Для n=429 - True
# Для n=430 - True
# Для n=431 - True
# Для n=432 - True
# Для n=433 - True
# Для n=434 - True
# Для n=435 - True
# Для n=436 - True
# Для n=437 - True
# Для n=438 - True
# Для n=439 - True
# Для n=440 - True
# Для n=441 - True
# Для n=442 - True
# Для n=443 - True
# Для n=444 - True
# Для n=445 - True
# Для n=446 - True
# Для n=447 - True
# Для n=448 - True
# Для n=449 - True
# Для n=450 - True
# Для n=451 - True
# Для n=452 - True
# Для n=453 - True
# Для n=454 - True
# Для n=455 - True
# Для n=456 - True
# Для n=457 - True
# Для n=458 - True
# Для n=459 - True
# Для n=460 - True
# Для n=461 - True
# Для n=462 - True
# Для n=463 - True
# Для n=464 - True
# Для n=465 - True
# Для n=466 - True
# Для n=467 - True
# Для n=468 - True
# Для n=469 - True
# Для n=470 - True
# Для n=471 - True
# Для n=472 - True
# Для n=473 - True
# Для n=474 - True
# Для n=475 - True
# Для n=476 - True
# Для n=477 - True
# Для n=478 - True
# Для n=479 - True
# Для n=480 - True
# Для n=481 - True
# Для n=482 - True
# Для n=483 - True
# Для n=484 - True
# Для n=485 - True
# Для n=486 - True
# Для n=487 - True
# Для n=488 - True
# Для n=489 - True
# Для n=490 - True
# Для n=491 - True
# Для n=492 - True
# Для n=493 - True
# Для n=494 - True
# Для n=495 - True
# Для n=496 - True
# Для n=497 - True
# Для n=498 - True
# Для n=499 - True
# Для n=500 - True
# Для n=501 - True
# Для n=502 - True
# Для n=503 - True
# Для n=504 - True
# Для n=505 - True
# Для n=506 - True
# Для n=507 - True
# Для n=508 - True
# Для n=509 - True
# Для n=510 - True
# Для n=511 - True
# Для n=512 - True
# Для n=513 - True
# Для n=514 - True
# Для n=515 - True
# Для n=516 - True
# Для n=517 - True
# Для n=518 - True
# Для n=519 - True
# Для n=520 - True
# Для n=521 - True
# Для n=522 - True
# Для n=523 - True
# Для n=524 - True
# Для n=525 - True
# Для n=526 - True
# Для n=527 - True
# Для n=528 - True
# Для n=529 - True
# Для n=530 - True
# Для n=531 - True
# Для n=532 - True
# Для n=533 - True
# Для n=534 - True
# Для n=535 - True
# Для n=536 - True
# Для n=537 - True
# Для n=538 - True
# Для n=539 - True
# Для n=540 - True
# Для n=541 - True
# Для n=542 - True
# Для n=543 - True
# Для n=544 - True
# Для n=545 - True
# Для n=546 - True
# Для n=547 - True
# Для n=548 - True
# Для n=549 - True
# Для n=550 - True
# Для n=551 - True
# Для n=552 - True
# Для n=553 - True
# Для n=554 - True
# Для n=555 - True
# Для n=556 - True
# Для n=557 - True
# Для n=558 - True
# Для n=559 - True
# Для n=560 - True
# Для n=561 - True
# Для n=562 - True
# Для n=563 - True
# Для n=564 - True
# Для n=565 - True
# Для n=566 - True
# Для n=567 - True
# Для n=568 - True
# Для n=569 - True
# Для n=570 - True
# Для n=571 - True
# Для n=572 - True
# Для n=573 - True
# Для n=574 - True
# Для n=575 - True
# Для n=576 - True
# Для n=577 - True
# Для n=578 - True
# Для n=579 - True
# Для n=580 - True
# Для n=581 - True
# Для n=582 - True
# Для n=583 - True
# Для n=584 - True
# Для n=585 - True
# Для n=586 - True
# Для n=587 - True
# Для n=588 - True
# Для n=589 - True
# Для n=590 - True
# Для n=591 - True
# Для n=592 - True
# Для n=593 - True
# Для n=594 - True
# Для n=595 - True
# Для n=596 - True
# Для n=597 - True
# Для n=598 - True
# Для n=599 - True
# Для n=600 - True
# Для n=601 - True
# Для n=602 - True
# Для n=603 - True
# Для n=604 - True
# Для n=605 - True
# Для n=606 - True
# Для n=607 - True
# Для n=608 - True
# Для n=609 - True
# Для n=610 - True
# Для n=611 - True
# Для n=612 - True
# Для n=613 - True
# Для n=614 - True
# Для n=615 - True
# Для n=616 - True
# Для n=617 - True
# Для n=618 - True
# Для n=619 - True
# Для n=620 - True
# Для n=621 - True
# Для n=622 - True
# Для n=623 - True
# Для n=624 - True
# Для n=625 - True
# Для n=626 - True
# Для n=627 - True
# Для n=628 - True
# Для n=629 - True
# Для n=630 - True
# Для n=631 - True
# Для n=632 - True
# Для n=633 - True
# Для n=634 - True
# Для n=635 - True
# Для n=636 - True
# Для n=637 - True
# Для n=638 - True
# Для n=639 - True
# Для n=640 - True
# Для n=641 - True
# Для n=642 - True
# Для n=643 - True
# Для n=644 - True
# Для n=645 - True
# Для n=646 - True
# Для n=647 - True
# Для n=648 - True
# Для n=649 - True
# Для n=650 - True
# Для n=651 - True
# Для n=652 - True
# Для n=653 - True
# Для n=654 - True
# Для n=655 - True
# Для n=656 - True
# Для n=657 - True
# Для n=658 - True
# Для n=659 - True
# Для n=660 - True
# Для n=661 - True
# Для n=662 - True
# Для n=663 - True
# Для n=664 - True
# Для n=665 - True
# Для n=666 - True
# Для n=667 - True
# Для n=668 - True
# Для n=669 - True
# Для n=670 - True
# Для n=671 - True
# Для n=672 - True
# Для n=673 - True
# Для n=674 - True
# Для n=675 - True
# Для n=676 - True
# Для n=677 - True
# Для n=678 - True
# Для n=679 - True
# Для n=680 - True
# Для n=681 - True
# Для n=682 - True
# Для n=683 - True
# Для n=684 - True
# Для n=685 - True
# Для n=686 - True
# Для n=687 - True
# Для n=688 - True
# Для n=689 - True
# Для n=690 - True
# Для n=691 - True
# Для n=692 - True
# Для n=693 - True
# Для n=694 - True
# Для n=695 - True
# Для n=696 - True
# Для n=697 - True
# Для n=698 - True
# Для n=699 - True
# Для n=700 - True
# Для n=701 - True
# Для n=702 - True
# Для n=703 - True
# Для n=704 - True
# Для n=705 - True
# Для n=706 - True
# Для n=707 - True
# Для n=708 - True
# Для n=709 - True
# Для n=710 - True
# Для n=711 - True
# Для n=712 - True
# Для n=713 - True
# Для n=714 - True
# Для n=715 - True
# Для n=716 - True
# Для n=717 - True
# Для n=718 - True
# Для n=719 - True
# Для n=720 - True
# Для n=721 - True
# Для n=722 - True
# Для n=723 - True
# Для n=724 - True
# Для n=725 - True
# Для n=726 - True
# Для n=727 - True
# Для n=728 - True
# Для n=729 - True
# Для n=730 - True
# Для n=731 - True
# Для n=732 - True
# Для n=733 - True
# Для n=734 - True
# Для n=735 - True
# Для n=736 - True
# Для n=737 - True
# Для n=738 - True
# Для n=739 - True
# Для n=740 - True
# Для n=741 - True
# Для n=742 - True
# Для n=743 - True
# Для n=744 - True
# Для n=745 - True
# Для n=746 - True
# Для n=747 - True
# Для n=748 - True
# Для n=749 - True
# Для n=750 - True
# Для n=751 - True
# Для n=752 - True
# Для n=753 - True
# Для n=754 - True
# Для n=755 - True
# Для n=756 - True
# Для n=757 - True
# Для n=758 - True
# Для n=759 - True
# Для n=760 - True
# Для n=761 - True
# Для n=762 - True
# Для n=763 - True
# Для n=764 - True
# Для n=765 - True
# Для n=766 - True
# Для n=767 - True
# Для n=768 - True
# Для n=769 - True
# Для n=770 - True
# Для n=771 - True
# Для n=772 - True
# Для n=773 - True
# Для n=774 - True
# Для n=775 - True
# Для n=776 - True
# Для n=777 - True
# Для n=778 - True
# Для n=779 - True
# Для n=780 - True
# Для n=781 - True
# Для n=782 - True
# Для n=783 - True
# Для n=784 - True
# Для n=785 - True
# Для n=786 - True
# Для n=787 - True
# Для n=788 - True
# Для n=789 - True
# Для n=790 - True
# Для n=791 - True
# Для n=792 - True
# Для n=793 - True
# Для n=794 - True
# Для n=795 - True
# Для n=796 - True
# Для n=797 - True
# Для n=798 - True
# Для n=799 - True
# Для n=800 - True
# Для n=801 - True
# Для n=802 - True
# Для n=803 - True
# Для n=804 - True
# Для n=805 - True
# Для n=806 - True
# Для n=807 - True
# Для n=808 - True
# Для n=809 - True
# Для n=810 - True
# Для n=811 - True
# Для n=812 - True
# Для n=813 - True
# Для n=814 - True
# Для n=815 - True
# Для n=816 - True
# Для n=817 - True
# Для n=818 - True
# Для n=819 - True
# Для n=820 - True
# Для n=821 - True
# Для n=822 - True
# Для n=823 - True
# Для n=824 - True
# Для n=825 - True
# Для n=826 - True
# Для n=827 - True
# Для n=828 - True
# Для n=829 - True
# Для n=830 - True
# Для n=831 - True
# Для n=832 - True
# Для n=833 - True
# Для n=834 - True
# Для n=835 - True
# Для n=836 - True
# Для n=837 - True
# Для n=838 - True
# Для n=839 - True
# Для n=840 - True
# Для n=841 - True
# Для n=842 - True
# Для n=843 - True
# Для n=844 - True
# Для n=845 - True
# Для n=846 - True
# Для n=847 - True
# Для n=848 - True
# Для n=849 - True
# Для n=850 - True
# Для n=851 - True
# Для n=852 - True
# Для n=853 - True
# Для n=854 - True
# Для n=855 - True
# Для n=856 - True
# Для n=857 - True
# Для n=858 - True
# Для n=859 - True
# Для n=860 - True
# Для n=861 - True
# Для n=862 - True
# Для n=863 - True
# Для n=864 - True
# Для n=865 - True
# Для n=866 - True
# Для n=867 - True
# Для n=868 - True
# Для n=869 - True
# Для n=870 - True
# Для n=871 - True
# Для n=872 - True
# Для n=873 - True
# Для n=874 - True
# Для n=875 - True
# Для n=876 - True
# Для n=877 - True
# Для n=878 - True
# Для n=879 - True
# Для n=880 - True
# Для n=881 - True
# Для n=882 - True
# Для n=883 - True
# Для n=884 - True
# Для n=885 - True
# Для n=886 - True
# Для n=887 - True
# Для n=888 - True
# Для n=889 - True
# Для n=890 - True
# Для n=891 - True
# Для n=892 - True
# Для n=893 - True
# Для n=894 - True
# Для n=895 - True
# Для n=896 - True
# Для n=897 - True
# Для n=898 - True
# Для n=899 - True
# Для n=900 - True
# Для n=901 - True
# Для n=902 - True
# Для n=903 - True
# Для n=904 - True
# Для n=905 - True
# Для n=906 - True
# Для n=907 - True
# Для n=908 - True
# Для n=909 - True
# Для n=910 - True
# Для n=911 - True
# Для n=912 - True
# Для n=913 - True
# Для n=914 - True
# Для n=915 - True
# Для n=916 - True
# Для n=917 - True
# Для n=918 - True
# Для n=919 - True
# Для n=920 - True
# Для n=921 - True
# Для n=922 - True
# Для n=923 - True
# Для n=924 - True
# Для n=925 - True
# Для n=926 - True
# Для n=927 - True
# Для n=928 - True
# Для n=929 - True
# Для n=930 - True
# Для n=931 - True
# Для n=932 - True
# Для n=933 - True
# Для n=934 - True
# Для n=935 - True
# Для n=936 - True
# Для n=937 - True
# Для n=938 - True
# Для n=939 - True
# Для n=940 - True
# Для n=941 - True
# Для n=942 - True
# Для n=943 - True
# Для n=944 - True
# Для n=945 - True
# Для n=946 - True
# Для n=947 - True
# Для n=948 - True
# Для n=949 - True
# Для n=950 - True
# Для n=951 - True
# Для n=952 - True
# Для n=953 - True
# Для n=954 - True
# Для n=955 - True
# Для n=956 - True
# Для n=957 - True
# Для n=958 - True
# Для n=959 - True
# Для n=960 - True
# Для n=961 - True
# Для n=962 - True
# Для n=963 - True
# Для n=964 - True
# Для n=965 - True
# Для n=966 - True
# Для n=967 - True
# Для n=968 - True
# Для n=969 - True
# Для n=970 - True
# Для n=971 - True
# Для n=972 - True
# Для n=973 - True
# Для n=974 - True
# Для n=975 - True
# Для n=976 - True
# Для n=977 - True
# Для n=978 - True
# Для n=979 - True
# Для n=980 - True
# Для n=981 - True
# Для n=982 - True
# Для n=983 - True
# Для n=984 - True
# Для n=985 - True
# Для n=986 - True
# Для n=987 - True
# Для n=988 - True
# Для n=989 - True
# Для n=990 - True
# Для n=991 - True
# Для n=992 - True
# Для n=993 - True
# Для n=994 - True
# Для n=995 - True
# Для n=996 - True
# Для n=997 - True
# Для n=998 - True
# Для n=999 - True
# Для n=1000 - True
# Для n=1001 - True
# Для n=1002 - True
# Для n=1003 - True
# Для n=1004 - True
# Для n=1005 - True
# Для n=1006 - True
# Для n=1007 - True
# Для n=1008 - True
# Для n=1009 - True
# Для n=1010 - True
# Для n=1011 - True
# Для n=1012 - True
# Для n=1013 - True
# Для n=1014 - True
# Для n=1015 - True
# Для n=1016 - True
# Для n=1017 - True
# Для n=1018 - True
# Для n=1019 - True
# Для n=1020 - True
# Для n=1021 - True
# Для n=1022 - True
# Для n=1023 - True
# Для n=1024 - True
# Для n=1025 - True
# Для n=1026 - True
# Для n=1027 - True
# Для n=1028 - True
# Для n=1029 - True
# Для n=1030 - True
# Для n=1031 - True
# Для n=1032 - True
# Для n=1033 - True
# Для n=1034 - True
# Для n=1035 - True
# Для n=1036 - True
# Для n=1037 - True
# Для n=1038 - True
# Для n=1039 - True
# Для n=1040 - True
# Для n=1041 - True
# Для n=1042 - True
# Для n=1043 - True
# Для n=1044 - True
# Для n=1045 - True
# Для n=1046 - True
# Для n=1047 - True
# Для n=1048 - True
# Для n=1049 - True
# Для n=1050 - True
# Для n=1051 - True
# Для n=1052 - True
# Для n=1053 - True
# Для n=1054 - True
# Для n=1055 - True
# Для n=1056 - True
# Для n=1057 - True
# Для n=1058 - True
# Для n=1059 - True
# Для n=1060 - True
# Для n=1061 - True
# Для n=1062 - True
# Для n=1063 - True
# Для n=1064 - True
# Для n=1065 - True
# Для n=1066 - True
# Для n=1067 - True
# Для n=1068 - True
# Для n=1069 - True
# Для n=1070 - True
# Для n=1071 - True
# Для n=1072 - True
# Для n=1073 - True
# Для n=1074 - True
# Для n=1075 - True
# Для n=1076 - True
# Для n=1077 - True
# Для n=1078 - True
# Для n=1079 - True
# Для n=1080 - True
# Для n=1081 - True
# Для n=1082 - True
# Для n=1083 - True
# Для n=1084 - True
# Для n=1085 - True
# Для n=1086 - True
# Для n=1087 - True
# Для n=1088 - True
# Для n=1089 - True
# Для n=1090 - True
# Для n=1091 - True
# Для n=1092 - True
# Для n=1093 - True
# Для n=1094 - True
# Для n=1095 - True
# Для n=1096 - True
# Для n=1097 - True
# Для n=1098 - True
# Для n=1099 - True
# Для n=1100 - True
# Для n=1101 - True
# Для n=1102 - True
# Для n=1103 - True
# Для n=1104 - True
# Для n=1105 - True
# Для n=1106 - True
# Для n=1107 - True
# Для n=1108 - True
# Для n=1109 - True
# Для n=1110 - True
# Для n=1111 - True
# Для n=1112 - True
# Для n=1113 - True
# Для n=1114 - True
# Для n=1115 - True
# Для n=1116 - True
# Для n=1117 - True
# Для n=1118 - True
# Для n=1119 - True
# Для n=1120 - True
# Для n=1121 - True
# Для n=1122 - True
# Для n=1123 - True
# Для n=1124 - True
# Для n=1125 - True
# Для n=1126 - True
# Для n=1127 - True
# Для n=1128 - True
# Для n=1129 - True
# Для n=1130 - True
# Для n=1131 - True
# Для n=1132 - True
# Для n=1133 - True
# Для n=1134 - True
# Для n=1135 - True
# Для n=1136 - True
# Для n=1137 - True
# Для n=1138 - True
# Для n=1139 - True
# Для n=1140 - True
# Для n=1141 - True
# Для n=1142 - True
# Для n=1143 - True
# Для n=1144 - True
# Для n=1145 - True
# Для n=1146 - True
# Для n=1147 - True
# Для n=1148 - True
# Для n=1149 - True
# Для n=1150 - True
# Для n=1151 - True
# Для n=1152 - True
# Для n=1153 - True
# Для n=1154 - True
# Для n=1155 - True
# Для n=1156 - True
# Для n=1157 - True
# Для n=1158 - True
# Для n=1159 - True
# Для n=1160 - True
# Для n=1161 - True
# Для n=1162 - True
# Для n=1163 - True
# Для n=1164 - True
# Для n=1165 - True
# Для n=1166 - True
# Для n=1167 - True
# Для n=1168 - True
# Для n=1169 - True
# Для n=1170 - True
# Для n=1171 - True
# Для n=1172 - True
# Для n=1173 - True
# Для n=1174 - True
# Для n=1175 - True
# Для n=1176 - True
# Для n=1177 - True
# Для n=1178 - True
# Для n=1179 - True
# Для n=1180 - True
# Для n=1181 - True
# Для n=1182 - True
# Для n=1183 - True
# Для n=1184 - True
# Для n=1185 - True
# Для n=1186 - True
# Для n=1187 - True
# Для n=1188 - True
# Для n=1189 - True
# Для n=1190 - True
# Для n=1191 - True
# Для n=1192 - True
# Для n=1193 - True
# Для n=1194 - True
# Для n=1195 - True
# Для n=1196 - True
# Для n=1197 - True
# Для n=1198 - True
# Для n=1199 - True
# Для n=1200 - True
# Для n=1201 - True
# Для n=1202 - True
# Для n=1203 - True
# Для n=1204 - True
# Для n=1205 - True
# Для n=1206 - True
# Для n=1207 - True
# Для n=1208 - True
# Для n=1209 - True
# Для n=1210 - True
# Для n=1211 - True
# Для n=1212 - True
# Для n=1213 - True
# Для n=1214 - True
# Для n=1215 - True
# Для n=1216 - True
# Для n=1217 - True
# Для n=1218 - True
# Для n=1219 - True
# Для n=1220 - True
# Для n=1221 - True
# Для n=1222 - True
# Для n=1223 - True
# Для n=1224 - True
# Для n=1225 - True
# Для n=1226 - True
# Для n=1227 - True
# Для n=1228 - True
# Для n=1229 - True
# Для n=1230 - True
# Для n=1231 - True
# Для n=1232 - True
# Для n=1233 - True
# Для n=1234 - True
# Для n=1235 - True
# Для n=1236 - True
# Для n=1237 - True
# Для n=1238 - True
# Для n=1239 - True
# Для n=1240 - True
# Для n=1241 - True
# Для n=1242 - True
# Для n=1243 - True
# Для n=1244 - True
# Для n=1245 - True
# Для n=1246 - True
# Для n=1247 - True
# Для n=1248 - True
# Для n=1249 - True
# Для n=1250 - True
# Для n=1251 - True
# Для n=1252 - True
# Для n=1253 - True
# Для n=1254 - True
# Для n=1255 - True
# Для n=1256 - True
# Для n=1257 - True
# Для n=1258 - True
# Для n=1259 - True
# Для n=1260 - True
# Для n=1261 - True
# Для n=1262 - True
# Для n=1263 - True
# Для n=1264 - True
# Для n=1265 - True
# Для n=1266 - True
# Для n=1267 - True
# Для n=1268 - True
# Для n=1269 - True
# Для n=1270 - True
# Для n=1271 - True
# Для n=1272 - True
# Для n=1273 - True
# Для n=1274 - True
# Для n=1275 - True
# Для n=1276 - True
# Для n=1277 - True
# Для n=1278 - True
# Для n=1279 - True
# Для n=1280 - True
# Для n=1281 - True
# Для n=1282 - True
# Для n=1283 - True
# Для n=1284 - True
# Для n=1285 - True
# Для n=1286 - True
# Для n=1287 - True
# Для n=1288 - True
# Для n=1289 - True
# Для n=1290 - True
# Для n=1291 - True
# Для n=1292 - True
# Для n=1293 - True
# Для n=1294 - True
# Для n=1295 - True
# Для n=1296 - True
# Для n=1297 - True
# Для n=1298 - True
# Для n=1299 - True
# Для n=1300 - True
# Для n=1301 - True
# Для n=1302 - True
# Для n=1303 - True
# Для n=1304 - True
# Для n=1305 - True
# Для n=1306 - True
# Для n=1307 - True
# Для n=1308 - True
# Для n=1309 - True
# Для n=1310 - True
# Для n=1311 - True
# Для n=1312 - True
# Для n=1313 - True
# Для n=1314 - True
# Для n=1315 - True
# Для n=1316 - True
# Для n=1317 - True
# Для n=1318 - True
# Для n=1319 - True
# Для n=1320 - True
# Для n=1321 - True
# Для n=1322 - True
# Для n=1323 - True
# Для n=1324 - True
# Для n=1325 - True
# Для n=1326 - True
# Для n=1327 - True
# Для n=1328 - True
# Для n=1329 - True
# Для n=1330 - True
# Для n=1331 - True
# Для n=1332 - True
# Для n=1333 - True
# Для n=1334 - True
# Для n=1335 - True
# Для n=1336 - True
# Для n=1337 - True
# Для n=1338 - True
# Для n=1339 - True
# Для n=1340 - True
# Для n=1341 - True
# Для n=1342 - True
# Для n=1343 - True
# Для n=1344 - True
# Для n=1345 - True
# Для n=1346 - True
# Для n=1347 - True
# Для n=1348 - True
# Для n=1349 - True
# Для n=1350 - True
# Для n=1351 - True
# Для n=1352 - True
# Для n=1353 - True
# Для n=1354 - True
# Для n=1355 - True
# Для n=1356 - True
# Для n=1357 - True
# Для n=1358 - True
# Для n=1359 - True
# Для n=1360 - True
# Для n=1361 - True
# Для n=1362 - True
# Для n=1363 - True
# Для n=1364 - True
# Для n=1365 - True
# Для n=1366 - True
# Для n=1367 - True
# Для n=1368 - True
# Для n=1369 - True
# Для n=1370 - True
# Для n=1371 - True
# Для n=1372 - True
# Для n=1373 - True
# Для n=1374 - True
# Для n=1375 - True
# Для n=1376 - True
# Для n=1377 - True
# Для n=1378 - True
# Для n=1379 - True
# Для n=1380 - True
# Для n=1381 - True
# Для n=1382 - True
# Для n=1383 - True
# Для n=1384 - True
# Для n=1385 - True
# Для n=1386 - True
# Для n=1387 - True
# Для n=1388 - True
# Для n=1389 - True
# Для n=1390 - True
# Для n=1391 - True
# Для n=1392 - True
# Для n=1393 - True
# Для n=1394 - True
# Для n=1395 - True
# Для n=1396 - True
# Для n=1397 - True
# Для n=1398 - True
# Для n=1399 - True
# Для n=1400 - True
# Для n=1401 - True
# Для n=1402 - True
# Для n=1403 - True
# Для n=1404 - True
# Для n=1405 - True
# Для n=1406 - True
# Для n=1407 - True
# Для n=1408 - True
# Для n=1409 - True
# Для n=1410 - True
# Для n=1411 - True
# Для n=1412 - True
# Для n=1413 - True
# Для n=1414 - True
# Для n=1415 - True
# Для n=1416 - True
# Для n=1417 - True
# Для n=1418 - True
# Для n=1419 - True
# Для n=1420 - True
# Для n=1421 - True
# Для n=1422 - True
# Для n=1423 - True
# Для n=1424 - True
# Для n=1425 - True
# Для n=1426 - True
# Для n=1427 - True
# Для n=1428 - True
# Для n=1429 - True
# Для n=1430 - True
# Для n=1431 - True
# Для n=1432 - True
# Для n=1433 - True
# Для n=1434 - True
# Для n=1435 - True
# Для n=1436 - True
# Для n=1437 - True
# Для n=1438 - True
# Для n=1439 - True
# Для n=1440 - True
# Для n=1441 - True
# Для n=1442 - True
# Для n=1443 - True
# Для n=1444 - True
# Для n=1445 - True
# Для n=1446 - True
# Для n=1447 - True
# Для n=1448 - True
# Для n=1449 - True
# Для n=1450 - True
# Для n=1451 - True
# Для n=1452 - True
# Для n=1453 - True
# Для n=1454 - True
# Для n=1455 - True
# Для n=1456 - True
# Для n=1457 - True
# Для n=1458 - True
# Для n=1459 - True
# Для n=1460 - True
# Для n=1461 - True
# Для n=1462 - True
# Для n=1463 - True
# Для n=1464 - True
# Для n=1465 - True
# Для n=1466 - True
# Для n=1467 - True
# Для n=1468 - True
# Для n=1469 - True
# Для n=1470 - True
# Для n=1471 - True
# Для n=1472 - True
# Для n=1473 - True
# Для n=1474 - True
# Для n=1475 - True
# Для n=1476 - True
# Для n=1477 - True
# Для n=1478 - True
# Для n=1479 - True
# Для n=1480 - True
# Для n=1481 - True
# Для n=1482 - True
# Для n=1483 - True
# Для n=1484 - True
# Для n=1485 - True
# Для n=1486 - True
# Для n=1487 - True
# Для n=1488 - True
# Для n=1489 - True
# Для n=1490 - True
# Для n=1491 - True
# Для n=1492 - True
# Для n=1493 - True
# Для n=1494 - True
# Для n=1495 - True
# Для n=1496 - True
# Для n=1497 - True
# Для n=1498 - True
# Для n=1499 - True
# Для n=1500 - True
# Для n=1501 - True
# Для n=1502 - True
# Для n=1503 - True
# Для n=1504 - True
# Для n=1505 - True
# Для n=1506 - True
# Для n=1507 - True
# Для n=1508 - True
# Для n=1509 - True
# Для n=1510 - True
# Для n=1511 - True
# Для n=1512 - True
# Для n=1513 - True
# Для n=1514 - True
# Для n=1515 - True
# Для n=1516 - True
# Для n=1517 - True
# Для n=1518 - True
# Для n=1519 - True
# Для n=1520 - True
# Для n=1521 - True
# Для n=1522 - True
# Для n=1523 - True
# Для n=1524 - True
# Для n=1525 - True
# Для n=1526 - True
# Для n=1527 - True
# Для n=1528 - True
# Для n=1529 - True
# Для n=1530 - True
# Для n=1531 - True
# Для n=1532 - True
# Для n=1533 - True
# Для n=1534 - True
# Для n=1535 - True
# Для n=1536 - True
# Для n=1537 - True
# Для n=1538 - True
# Для n=1539 - True
# Для n=1540 - True
# Для n=1541 - True
# Для n=1542 - True
# Для n=1543 - True
# Для n=1544 - True
# Для n=1545 - True
# Для n=1546 - True
# Для n=1547 - True
# Для n=1548 - True
# Для n=1549 - True
# Для n=1550 - True
# Для n=1551 - True
# Для n=1552 - True
# Для n=1553 - True
# Для n=1554 - True
# Для n=1555 - True
# Для n=1556 - True
# Для n=1557 - True
# Для n=1558 - True
# Для n=1559 - True
# Для n=1560 - True
# Для n=1561 - True
# Для n=1562 - True
# Для n=1563 - True
# Для n=1564 - True
# Для n=1565 - True
# Для n=1566 - True
# Для n=1567 - True
# Для n=1568 - True
# Для n=1569 - True
# Для n=1570 - True
# Для n=1571 - True
# Для n=1572 - True
# Для n=1573 - True
# Для n=1574 - True
# Для n=1575 - True
# Для n=1576 - True
# Для n=1577 - True
# Для n=1578 - True
# Для n=1579 - True
# Для n=1580 - True
# Для n=1581 - True
# Для n=1582 - True
# Для n=1583 - True
# Для n=1584 - True
# Для n=1585 - True
# Для n=1586 - True
# Для n=1587 - True
# Для n=1588 - True
# Для n=1589 - True
# Для n=1590 - True
# Для n=1591 - True
# Для n=1592 - True
# Для n=1593 - True
# Для n=1594 - True
# Для n=1595 - True
# Для n=1596 - True
# Для n=1597 - True
# Для n=1598 - True
# Для n=1599 - True
# Для n=1600 - True
# Для n=1601 - True
# Для n=1602 - True
# Для n=1603 - True
# Для n=1604 - True
# Для n=1605 - True
# Для n=1606 - True
# Для n=1607 - True
# Для n=1608 - True
# Для n=1609 - True
# Для n=1610 - True
# Для n=1611 - True
# Для n=1612 - True
# Для n=1613 - True
# Для n=1614 - True
# Для n=1615 - True
# Для n=1616 - True
# Для n=1617 - True
# Для n=1618 - True
# Для n=1619 - True
# Для n=1620 - True
# Для n=1621 - True
# Для n=1622 - True
# Для n=1623 - True
# Для n=1624 - True
# Для n=1625 - True
# Для n=1626 - True
# Для n=1627 - True
# Для n=1628 - True
# Для n=1629 - True
# Для n=1630 - True
# Для n=1631 - True
# Для n=1632 - True
# Для n=1633 - True
# Для n=1634 - True
# Для n=1635 - True
# Для n=1636 - True
# Для n=1637 - True
# Для n=1638 - True
# Для n=1639 - True
# Для n=1640 - True
# Для n=1641 - True
# Для n=1642 - True
# Для n=1643 - True
# Для n=1644 - True
# Для n=1645 - True
# Для n=1646 - True
# Для n=1647 - True
# Для n=1648 - True
# Для n=1649 - True
# Для n=1650 - True
# Для n=1651 - True
# Для n=1652 - True
# Для n=1653 - True
# Для n=1654 - True
# Для n=1655 - True
# Для n=1656 - True
# Для n=1657 - True
# Для n=1658 - True
# Для n=1659 - True
# Для n=1660 - True
# Для n=1661 - True
# Для n=1662 - True
# Для n=1663 - True
# Для n=1664 - True
# Для n=1665 - True
# Для n=1666 - True
# Для n=1667 - True
# Для n=1668 - True
# Для n=1669 - True
# Для n=1670 - True
# Для n=1671 - True
# Для n=1672 - True
# Для n=1673 - True
# Для n=1674 - True
# Для n=1675 - True
# Для n=1676 - True
# Для n=1677 - True
# Для n=1678 - True
# Для n=1679 - True
# Для n=1680 - True
# Для n=1681 - True
# Для n=1682 - True
# Для n=1683 - True
# Для n=1684 - True
# Для n=1685 - True
# Для n=1686 - True
# Для n=1687 - True
# Для n=1688 - True
# Для n=1689 - True
# Для n=1690 - True
# Для n=1691 - True
# Для n=1692 - True
# Для n=1693 - True
# Для n=1694 - True
# Для n=1695 - True
# Для n=1696 - True
# Для n=1697 - True
# Для n=1698 - True
# Для n=1699 - True
# Для n=1700 - True
# Для n=1701 - True
# Для n=1702 - True
# Для n=1703 - True
# Для n=1704 - True
# Для n=1705 - True
# Для n=1706 - True
# Для n=1707 - True
# Для n=1708 - True
# Для n=1709 - True
# Для n=1710 - True
# Для n=1711 - True
# Для n=1712 - True
# Для n=1713 - True
# Для n=1714 - True
# Для n=1715 - True
# Для n=1716 - True
# Для n=1717 - True
# Для n=1718 - True
# Для n=1719 - True
# Для n=1720 - True
# Для n=1721 - True
# Для n=1722 - True
# Для n=1723 - True
# Для n=1724 - True
# Для n=1725 - True
# Для n=1726 - True
# Для n=1727 - True
# Для n=1728 - True
# Для n=1729 - True
# Для n=1730 - True
# Для n=1731 - True
# Для n=1732 - True
# Для n=1733 - True
# Для n=1734 - True
# Для n=1735 - True
# Для n=1736 - True
# Для n=1737 - True
# Для n=1738 - True
# Для n=1739 - True
# Для n=1740 - True
# Для n=1741 - True
# Для n=1742 - True
# Для n=1743 - True
# Для n=1744 - True
# Для n=1745 - True
# Для n=1746 - True
# Для n=1747 - True
# Для n=1748 - True
# Для n=1749 - True
# Для n=1750 - True
# Для n=1751 - True
# Для n=1752 - True
# Для n=1753 - True
# Для n=1754 - True
# Для n=1755 - True
# Для n=1756 - True
# Для n=1757 - True
# Для n=1758 - True
# Для n=1759 - True
# Для n=1760 - True
# Для n=1761 - True
# Для n=1762 - True
# Для n=1763 - True
# Для n=1764 - True
# Для n=1765 - True
# Для n=1766 - True
# Для n=1767 - True
# Для n=1768 - True
# Для n=1769 - True
# Для n=1770 - True
# Для n=1771 - True
# Для n=1772 - True
# Для n=1773 - True
# Для n=1774 - True
# Для n=1775 - True
# Для n=1776 - True
# Для n=1777 - True
# Для n=1778 - True
# Для n=1779 - True
# Для n=1780 - True
# Для n=1781 - True
# Для n=1782 - True
# Для n=1783 - True
# Для n=1784 - True
# Для n=1785 - True
# Для n=1786 - True
# Для n=1787 - True
# Для n=1788 - True
# Для n=1789 - True
# Для n=1790 - True
# Для n=1791 - True
# Для n=1792 - True
# Для n=1793 - True
# Для n=1794 - True
# Для n=1795 - True
# Для n=1796 - True
# Для n=1797 - True
# Для n=1798 - True
# Для n=1799 - True
# Для n=1800 - True
# Для n=1801 - True
# Для n=1802 - True
# Для n=1803 - True
# Для n=1804 - True
# Для n=1805 - True
# Для n=1806 - True
# Для n=1807 - True
# Для n=1808 - True
# Для n=1809 - True
# Для n=1810 - True
# Для n=1811 - True
# Для n=1812 - True
# Для n=1813 - True
# Для n=1814 - True
# Для n=1815 - True
# Для n=1816 - True
# Для n=1817 - True
# Для n=1818 - True
# Для n=1819 - True
# Для n=1820 - True
# Для n=1821 - True
# Для n=1822 - True
# Для n=1823 - True
# Для n=1824 - True
# Для n=1825 - True
# Для n=1826 - True
# Для n=1827 - True
# Для n=1828 - True
# Для n=1829 - True
# Для n=1830 - True
# Для n=1831 - True
# Для n=1832 - True
# Для n=1833 - True
# Для n=1834 - True
# Для n=1835 - True
# Для n=1836 - True
# Для n=1837 - True
# Для n=1838 - True
# Для n=1839 - True
# Для n=1840 - True
# Для n=1841 - True
# Для n=1842 - True
# Для n=1843 - True
# Для n=1844 - True
# Для n=1845 - True
# Для n=1846 - True
# Для n=1847 - True
# Для n=1848 - True
# Для n=1849 - True
# Для n=1850 - True
# Для n=1851 - True
# Для n=1852 - True
# Для n=1853 - True
# Для n=1854 - True
# Для n=1855 - True
# Для n=1856 - True
# Для n=1857 - True
# Для n=1858 - True
# Для n=1859 - True
# Для n=1860 - True
# Для n=1861 - True
# Для n=1862 - True
# Для n=1863 - True
# Для n=1864 - True
# Для n=1865 - True
# Для n=1866 - True
# Для n=1867 - True
# Для n=1868 - True
# Для n=1869 - True
# Для n=1870 - True
# Для n=1871 - True
# Для n=1872 - True
# Для n=1873 - True
# Для n=1874 - True
# Для n=1875 - True
# Для n=1876 - True
# Для n=1877 - True
# Для n=1878 - True
# Для n=1879 - True
# Для n=1880 - True
# Для n=1881 - True
# Для n=1882 - True
# Для n=1883 - True
# Для n=1884 - True
# Для n=1885 - True
# Для n=1886 - True
# Для n=1887 - True
# Для n=1888 - True
# Для n=1889 - True
# Для n=1890 - True
# Для n=1891 - True
# Для n=1892 - True
# Для n=1893 - True
# Для n=1894 - True
# Для n=1895 - True
# Для n=1896 - True
# Для n=1897 - True
# Для n=1898 - True
# Для n=1899 - True
# Для n=1900 - True
# Для n=1901 - True
# Для n=1902 - True
# Для n=1903 - True
# Для n=1904 - True
# Для n=1905 - True
# Для n=1906 - True
# Для n=1907 - True
# Для n=1908 - True
# Для n=1909 - True
# Для n=1910 - True
# Для n=1911 - True
# Для n=1912 - True
# Для n=1913 - True
# Для n=1914 - True
# Для n=1915 - True
# Для n=1916 - True
# Для n=1917 - True
# Для n=1918 - True
# Для n=1919 - True
# Для n=1920 - True
# Для n=1921 - True
# Для n=1922 - True
# Для n=1923 - True
# Для n=1924 - True
# Для n=1925 - True
# Для n=1926 - True
# Для n=1927 - True
# Для n=1928 - True
# Для n=1929 - True
# Для n=1930 - True
# Для n=1931 - True
# Для n=1932 - True
# Для n=1933 - True
# Для n=1934 - True
# Для n=1935 - True
# Для n=1936 - True
# Для n=1937 - True
# Для n=1938 - True
# Для n=1939 - True
# Для n=1940 - True
# Для n=1941 - True
# Для n=1942 - True
# Для n=1943 - True
# Для n=1944 - True
# Для n=1945 - True
# Для n=1946 - True
# Для n=1947 - True
# Для n=1948 - True
# Для n=1949 - True
# Для n=1950 - True
# Для n=1951 - True
# Для n=1952 - True
# Для n=1953 - True
# Для n=1954 - True
# Для n=1955 - True
# Для n=1956 - True
# Для n=1957 - True
# Для n=1958 - True
# Для n=1959 - True
# Для n=1960 - True
# Для n=1961 - True
# Для n=1962 - True
# Для n=1963 - True
# Для n=1964 - True
# Для n=1965 - True
# Для n=1966 - True
# Для n=1967 - True
# Для n=1968 - True
# Для n=1969 - True
# Для n=1970 - True
# Для n=1971 - True
# Для n=1972 - True
# Для n=1973 - True
# Для n=1974 - True
# Для n=1975 - True
# Для n=1976 - True
# Для n=1977 - True
# Для n=1978 - True
# Для n=1979 - True
# Для n=1980 - True
# Для n=1981 - True
# Для n=1982 - True
# Для n=1983 - True
# Для n=1984 - True
# Для n=1985 - True
# Для n=1986 - True
# Для n=1987 - True
# Для n=1988 - True
# Для n=1989 - True
# Для n=1990 - True
# Для n=1991 - True
# Для n=1992 - True
# Для n=1993 - True
# Для n=1994 - True
# Для n=1995 - True
# Для n=1996 - True
# Для n=1997 - True
# Для n=1998 - True
# Для n=1999 - True
# Для n=2000 - True
# Для n=2001 - True
# Для n=2002 - True
# Для n=2003 - True
# Для n=2004 - True
# Для n=2005 - True
# Для n=2006 - True
# Для n=2007 - True
# Для n=2008 - True
# Для n=2009 - True
# Для n=2010 - True
# Для n=2011 - True
# Для n=2012 - True
# Для n=2013 - True
# Для n=2014 - True
# Для n=2015 - True
# Для n=2016 - True
# Для n=2017 - True
# Для n=2018 - True
# Для n=2019 - True
# Для n=2020 - True
# Для n=2021 - True
# Для n=2022 - True
# Для n=2023 - True
# Для n=2024 - True
# Для n=2025 - True
# Для n=2026 - True
# Для n=2027 - True
# Для n=2028 - True
# Для n=2029 - True
# Для n=2030 - True
# Для n=2031 - True
# Для n=2032 - True
# Для n=2033 - True
# Для n=2034 - True
# Для n=2035 - True
# Для n=2036 - True
# Для n=2037 - True
# Для n=2038 - True
# Для n=2039 - True
# Для n=2040 - True
# Для n=2041 - True
# Для n=2042 - True
# Для n=2043 - True
# Для n=2044 - True
# Для n=2045 - True
# Для n=2046 - True
# Для n=2047 - True
# Для n=2048 - True
# Для n=2049 - True
# Для n=2050 - True
# Для n=2051 - True
# Для n=2052 - True
# Для n=2053 - True
# Для n=2054 - True
# Для n=2055 - True
# Для n=2056 - True
# Для n=2057 - True
# Для n=2058 - True
# Для n=2059 - True
# Для n=2060 - True
# Для n=2061 - True
# Для n=2062 - True
# Для n=2063 - True
# Для n=2064 - True
# Для n=2065 - True
# Для n=2066 - True
# Для n=2067 - True
# Для n=2068 - True
# Для n=2069 - True
# Для n=2070 - True
# Для n=2071 - True
# Для n=2072 - True
# Для n=2073 - True
# Для n=2074 - True
# Для n=2075 - True
# Для n=2076 - True
# Для n=2077 - True
# Для n=2078 - True
# Для n=2079 - True
# Для n=2080 - True
# Для n=2081 - True
# Для n=2082 - True
# Для n=2083 - True
# Для n=2084 - True
# Для n=2085 - True
# Для n=2086 - True
# Для n=2087 - True
# Для n=2088 - True
# Для n=2089 - True
# Для n=2090 - True
# Для n=2091 - True
# Для n=2092 - True
# Для n=2093 - True
# Для n=2094 - True
# Для n=2095 - True
# Для n=2096 - True
# Для n=2097 - True
# Для n=2098 - True
# Для n=2099 - True
# Для n=2100 - True
# Для n=2101 - True
# Для n=2102 - True
# Для n=2103 - True
# Для n=2104 - True
# Для n=2105 - True
# Для n=2106 - True
# Для n=2107 - True
# Для n=2108 - True
# Для n=2109 - True
# Для n=2110 - True
# Для n=2111 - True
# Для n=2112 - True
# Для n=2113 - True
# Для n=2114 - True
# Для n=2115 - True
# Для n=2116 - True
# Для n=2117 - True
# Для n=2118 - True
# Для n=2119 - True
# Для n=2120 - True
# Для n=2121 - True
# Для n=2122 - True
# Для n=2123 - True
# Для n=2124 - True
# Для n=2125 - True
# Для n=2126 - True
# Для n=2127 - True
# Для n=2128 - True
# Для n=2129 - True
# Для n=2130 - True
# Для n=2131 - True
# Для n=2132 - True
# Для n=2133 - True
# Для n=2134 - True
# Для n=2135 - True
# Для n=2136 - True
# Для n=2137 - True
# Для n=2138 - True
# Для n=2139 - True
# Для n=2140 - True
# Для n=2141 - True
# Для n=2142 - True
# Для n=2143 - True
# Для n=2144 - True
# Для n=2145 - True
# Для n=2146 - True
# Для n=2147 - True
# Для n=2148 - True
# Для n=2149 - True
# Для n=2150 - True
# Для n=2151 - True
# Для n=2152 - True
# Для n=2153 - True
# Для n=2154 - True
# Для n=2155 - True
# Для n=2156 - True
# Для n=2157 - True
# Для n=2158 - True
# Для n=2159 - True
# Для n=2160 - True
# Для n=2161 - True
# Для n=2162 - True
# Для n=2163 - True
# Для n=2164 - True
# Для n=2165 - True
# Для n=2166 - True
# Для n=2167 - True
# Для n=2168 - True
# Для n=2169 - True
# Для n=2170 - True
# Для n=2171 - True
# Для n=2172 - True
# Для n=2173 - True
# Для n=2174 - True
# Для n=2175 - True
# Для n=2176 - True
# Для n=2177 - True
# Для n=2178 - True
# Для n=2179 - True
# Для n=2180 - True
# Для n=2181 - True
# Для n=2182 - True
# Для n=2183 - True
# Для n=2184 - True
# Для n=2185 - True
# Для n=2186 - True
# Для n=2187 - True
# Для n=2188 - True
# Для n=2189 - True
# Для n=2190 - True
# Для n=2191 - True
# Для n=2192 - True
# Для n=2193 - True
# Для n=2194 - True
# Для n=2195 - True
# Для n=2196 - True
# Для n=2197 - True
# Для n=2198 - True
# Для n=2199 - True
# Для n=2200 - True
# Для n=2201 - True
# Для n=2202 - True
# Для n=2203 - True
# Для n=2204 - True
# Для n=2205 - True
# Для n=2206 - True
# Для n=2207 - True
# Для n=2208 - True
# Для n=2209 - True
# Для n=2210 - True
# Для n=2211 - True
# Для n=2212 - True
# Для n=2213 - True
# Для n=2214 - True
# Для n=2215 - True
# Для n=2216 - True
# Для n=2217 - True
# Для n=2218 - True
# Для n=2219 - True
# Для n=2220 - True
# Для n=2221 - True
# Для n=2222 - True
# Для n=2223 - True
# Для n=2224 - True
# Для n=2225 - True
# Для n=2226 - True
# Для n=2227 - True
# Для n=2228 - True
# Для n=2229 - True
# Для n=2230 - True
# Для n=2231 - True
# Для n=2232 - True
# Для n=2233 - True
# Для n=2234 - True
# Для n=2235 - True
# Для n=2236 - True
# Для n=2237 - True
# Для n=2238 - True
# Для n=2239 - True
# Для n=2240 - True
# Для n=2241 - True
# Для n=2242 - True
# Для n=2243 - True
# Для n=2244 - True
# Для n=2245 - True
# Для n=2246 - True
# Для n=2247 - True
# Для n=2248 - True
# Для n=2249 - True
# Для n=2250 - True
# Для n=2251 - True
# Для n=2252 - True
# Для n=2253 - True
# Для n=2254 - True
# Для n=2255 - True
# Для n=2256 - True
# Для n=2257 - True
# Для n=2258 - True
# Для n=2259 - True
# Для n=2260 - True
# Для n=2261 - True
# Для n=2262 - True
# Для n=2263 - True
# Для n=2264 - True
# Для n=2265 - True
# Для n=2266 - True
# Для n=2267 - True
# Для n=2268 - True
# Для n=2269 - True
# Для n=2270 - True
# Для n=2271 - True
# Для n=2272 - True
# Для n=2273 - True
# Для n=2274 - True
# Для n=2275 - True
# Для n=2276 - True
# Для n=2277 - True
# Для n=2278 - True
# Для n=2279 - True
# Для n=2280 - True
# Для n=2281 - True
# Для n=2282 - True
# Для n=2283 - True
# Для n=2284 - True
# Для n=2285 - True
# Для n=2286 - True
# Для n=2287 - True
# Для n=2288 - True
# Для n=2289 - True
# Для n=2290 - True
# Для n=2291 - True
# Для n=2292 - True
# Для n=2293 - True
# Для n=2294 - True
# Для n=2295 - True
# Для n=2296 - True
# Для n=2297 - True
# Для n=2298 - True
# Для n=2299 - True
# Для n=2300 - True
# Для n=2301 - True
# Для n=2302 - True
# Для n=2303 - True
# Для n=2304 - True
# Для n=2305 - True
# Для n=2306 - True
# Для n=2307 - True
# Для n=2308 - True
# Для n=2309 - True
# Для n=2310 - True
# Для n=2311 - True
# Для n=2312 - True
# Для n=2313 - True
# Для n=2314 - True
# Для n=2315 - True
# Для n=2316 - True
# Для n=2317 - True
# Для n=2318 - True
# Для n=2319 - True
# Для n=2320 - True
# Для n=2321 - True
# Для n=2322 - True
# Для n=2323 - True
# Для n=2324 - True
# Для n=2325 - True
# Для n=2326 - True
# Для n=2327 - True
# Для n=2328 - True
# Для n=2329 - True
# Для n=2330 - True
# Для n=2331 - True
# Для n=2332 - True
# Для n=2333 - True
# Для n=2334 - True
# Для n=2335 - True
# Для n=2336 - True
# Для n=2337 - True
# Для n=2338 - True
# Для n=2339 - True
# Для n=2340 - True
# Для n=2341 - True
# Для n=2342 - True
# Для n=2343 - True
# Для n=2344 - True
# Для n=2345 - True
# Для n=2346 - True
# Для n=2347 - True
# Для n=2348 - True
# Для n=2349 - True
# Для n=2350 - True
# Для n=2351 - True
# Для n=2352 - True
# Для n=2353 - True
# Для n=2354 - True
# Для n=2355 - True
# Для n=2356 - True
# Для n=2357 - True
# Для n=2358 - True
# Для n=2359 - True
# Для n=2360 - True
# Для n=2361 - True
# Для n=2362 - True
# Для n=2363 - True
# Для n=2364 - True
# Для n=2365 - True
# Для n=2366 - True
# Для n=2367 - True
# Для n=2368 - True
# Для n=2369 - True
# Для n=2370 - True
# Для n=2371 - True
# Для n=2372 - True
# Для n=2373 - True
# Для n=2374 - True
# Для n=2375 - True
# Для n=2376 - True
# Для n=2377 - True
# Для n=2378 - True
# Для n=2379 - True
# Для n=2380 - True
# Для n=2381 - True
# Для n=2382 - True
# Для n=2383 - True
# Для n=2384 - True
# Для n=2385 - True
# Для n=2386 - True
# Для n=2387 - True
# Для n=2388 - True
# Для n=2389 - True
# Для n=2390 - True
# Для n=2391 - True
# Для n=2392 - True
# Для n=2393 - True
# Для n=2394 - True
# Для n=2395 - True
# Для n=2396 - True
# Для n=2397 - True
# Для n=2398 - True
# Для n=2399 - True
# Для n=2400 - True
# Для n=2401 - True
# Для n=2402 - True
# Для n=2403 - True
# Для n=2404 - True
# Для n=2405 - True
# Для n=2406 - True
# Для n=2407 - True
# Для n=2408 - True
# Для n=2409 - True
# Для n=2410 - True
# Для n=2411 - True
# Для n=2412 - True
# Для n=2413 - True
# Для n=2414 - True
# Для n=2415 - True
# Для n=2416 - True
# Для n=2417 - True
# Для n=2418 - True
# Для n=2419 - True
# Для n=2420 - True
# Для n=2421 - True
# Для n=2422 - True
# Для n=2423 - True
# Для n=2424 - True
# Для n=2425 - True
# Для n=2426 - True
# Для n=2427 - True
# Для n=2428 - True
# Для n=2429 - True
# Для n=2430 - True
# Для n=2431 - True
# Для n=2432 - True
# Для n=2433 - True
# Для n=2434 - True
# Для n=2435 - True
# Для n=2436 - True
# Для n=2437 - True
# Для n=2438 - True
# Для n=2439 - True
# Для n=2440 - True
# Для n=2441 - True
# Для n=2442 - True
# Для n=2443 - True
# Для n=2444 - True
# Для n=2445 - True
# Для n=2446 - True
# Для n=2447 - True
# Для n=2448 - True
# Для n=2449 - True
# Для n=2450 - True
# Для n=2451 - True
# Для n=2452 - True
# Для n=2453 - True
# Для n=2454 - True
# Для n=2455 - True
# Для n=2456 - True
# Для n=2457 - True
# Для n=2458 - True
# Для n=2459 - True
# Для n=2460 - True
# Для n=2461 - True
# Для n=2462 - True
# Для n=2463 - True
# Для n=2464 - True
# Для n=2465 - True
# Для n=2466 - True
# Для n=2467 - True
# Для n=2468 - True
# Для n=2469 - True
# Для n=2470 - True
# Для n=2471 - True
# Для n=2472 - True
# Для n=2473 - True
# Для n=2474 - True
# Для n=2475 - True
# Для n=2476 - True
# Для n=2477 - True
# Для n=2478 - True
# Для n=2479 - True
# Для n=2480 - True
# Для n=2481 - True
# Для n=2482 - True
# Для n=2483 - True
# Для n=2484 - True
# Для n=2485 - True
# Для n=2486 - True
# Для n=2487 - True
# Для n=2488 - True
# Для n=2489 - True
# Для n=2490 - True
# Для n=2491 - True
# Для n=2492 - True
# Для n=2493 - True
# Для n=2494 - True
# Для n=2495 - True
# Для n=2496 - True
# Для n=2497 - True
# Для n=2498 - True
# Для n=2499 - True
# Для n=2500 - True
# Для n=2501 - True
# Для n=2502 - True
# Для n=2503 - True
# Для n=2504 - True
# Для n=2505 - True
# Для n=2506 - True
# Для n=2507 - True
# Для n=2508 - True
# Для n=2509 - True
# Для n=2510 - True
# Для n=2511 - True
# Для n=2512 - True
# Для n=2513 - True
# Для n=2514 - True
# Для n=2515 - True
# Для n=2516 - True
# Для n=2517 - True
# Для n=2518 - True
# Для n=2519 - True
# Для n=2520 - True
# Для n=2521 - True
# Для n=2522 - True
# Для n=2523 - True
# Для n=2524 - True
# Для n=2525 - True
# Для n=2526 - True
# Для n=2527 - True
# Для n=2528 - True
# Для n=2529 - True
# Для n=2530 - True
# Для n=2531 - True
# Для n=2532 - True
# Для n=2533 - True
# Для n=2534 - True
# Для n=2535 - True
# Для n=2536 - True
# Для n=2537 - True
# Для n=2538 - True
# Для n=2539 - True
# Для n=2540 - True
# Для n=2541 - True
# Для n=2542 - True
# Для n=2543 - True
# Для n=2544 - True
# Для n=2545 - True
# Для n=2546 - True
# Для n=2547 - True
# Для n=2548 - True
# Для n=2549 - True
# Для n=2550 - True
# Для n=2551 - True
# Для n=2552 - True
# Для n=2553 - True
# Для n=2554 - True
# Для n=2555 - True
# Для n=2556 - True
# Для n=2557 - True
# Для n=2558 - True
# Для n=2559 - True
# Для n=2560 - True
# Для n=2561 - True
# Для n=2562 - True
# Для n=2563 - True
# Для n=2564 - True
# Для n=2565 - True
# Для n=2566 - True
# Для n=2567 - True
# Для n=2568 - True
# Для n=2569 - True
# Для n=2570 - True
# Для n=2571 - True
# Для n=2572 - True
# Для n=2573 - True
# Для n=2574 - True
# Для n=2575 - True
# Для n=2576 - True
# Для n=2577 - True
# Для n=2578 - True
# Для n=2579 - True
# Для n=2580 - True
# Для n=2581 - True
# Для n=2582 - True
# Для n=2583 - True
# Для n=2584 - True
# Для n=2585 - True
# Для n=2586 - True
# Для n=2587 - True
# Для n=2588 - True
# Для n=2589 - True
# Для n=2590 - True
# Для n=2591 - True
# Для n=2592 - True
# Для n=2593 - True
# Для n=2594 - True
# Для n=2595 - True
# Для n=2596 - True
# Для n=2597 - True
# Для n=2598 - True
# Для n=2599 - True
# Для n=2600 - True
# Для n=2601 - True
# Для n=2602 - True
# Для n=2603 - True
# Для n=2604 - True
# Для n=2605 - True
# Для n=2606 - True
# Для n=2607 - True
# Для n=2608 - True
# Для n=2609 - True
# Для n=2610 - True
# Для n=2611 - True
# Для n=2612 - True
# Для n=2613 - True
# Для n=2614 - True
# Для n=2615 - True
# Для n=2616 - True
# Для n=2617 - True
# Для n=2618 - True
# Для n=2619 - True
# Для n=2620 - True
# Для n=2621 - True
# Для n=2622 - True
# Для n=2623 - True
# Для n=2624 - True
# Для n=2625 - True
# Для n=2626 - True
# Для n=2627 - True
# Для n=2628 - True
# Для n=2629 - True
# Для n=2630 - True
# Для n=2631 - True
# Для n=2632 - True
# Для n=2633 - True
# Для n=2634 - True
# Для n=2635 - True
# Для n=2636 - True
# Для n=2637 - True
# Для n=2638 - True
# Для n=2639 - True
# Для n=2640 - True
# Для n=2641 - True
# Для n=2642 - True
# Для n=2643 - True
# Для n=2644 - True
# Для n=2645 - True
# Для n=2646 - True
# Для n=2647 - True
# Для n=2648 - True
# Для n=2649 - True
# Для n=2650 - True
# Для n=2651 - True
# Для n=2652 - True
# Для n=2653 - True
# Для n=2654 - True
# Для n=2655 - True
# Для n=2656 - True
# Для n=2657 - True
# Для n=2658 - True
# Для n=2659 - True
# Для n=2660 - True
# Для n=2661 - True
# Для n=2662 - True
# Для n=2663 - True
# Для n=2664 - True
# Для n=2665 - True
# Для n=2666 - True
# Для n=2667 - True
# Для n=2668 - True
# Для n=2669 - True
# Для n=2670 - True
# Для n=2671 - True
# Для n=2672 - True
# Для n=2673 - True
# Для n=2674 - True
# Для n=2675 - True
# Для n=2676 - True
# Для n=2677 - True
# Для n=2678 - True
# Для n=2679 - True
# Для n=2680 - True
# Для n=2681 - True
# Для n=2682 - True
# Для n=2683 - True
# Для n=2684 - True
# Для n=2685 - True
# Для n=2686 - True
# Для n=2687 - True
# Для n=2688 - True
# Для n=2689 - True
# Для n=2690 - True
# Для n=2691 - True
# Для n=2692 - True
# Для n=2693 - True
# Для n=2694 - True
# Для n=2695 - True
# Для n=2696 - True
# Для n=2697 - True
# Для n=2698 - True
# Для n=2699 - True
# Для n=2700 - True
# Для n=2701 - True
# Для n=2702 - True
# Для n=2703 - True
# Для n=2704 - True
# Для n=2705 - True
# Для n=2706 - True
# Для n=2707 - True
# Для n=2708 - True
# Для n=2709 - True
# Для n=2710 - True
# Для n=2711 - True
# Для n=2712 - True
# Для n=2713 - True
# Для n=2714 - True
# Для n=2715 - True
# Для n=2716 - True
# Для n=2717 - True
# Для n=2718 - True
# Для n=2719 - True
# Для n=2720 - True
# Для n=2721 - True
# Для n=2722 - True
# Для n=2723 - True
# Для n=2724 - True
# Для n=2725 - True
# Для n=2726 - True
# Для n=2727 - True
# Для n=2728 - True
# Для n=2729 - True
# Для n=2730 - True
# Для n=2731 - True
# Для n=2732 - True
# Для n=2733 - True
# Для n=2734 - True
# Для n=2735 - True
# Для n=2736 - True
# Для n=2737 - True
# Для n=2738 - True
# Для n=2739 - True
# Для n=2740 - True
# Для n=2741 - True
# Для n=2742 - True
# Для n=2743 - True
# Для n=2744 - True
# Для n=2745 - True
# Для n=2746 - True
# Для n=2747 - True
# Для n=2748 - True
# Для n=2749 - True
# Для n=2750 - True
# Для n=2751 - True
# Для n=2752 - True
# Для n=2753 - True
# Для n=2754 - True
# Для n=2755 - True
# Для n=2756 - True
# Для n=2757 - True
# Для n=2758 - True
# Для n=2759 - True
# Для n=2760 - True
# Для n=2761 - True
# Для n=2762 - True
# Для n=2763 - True
# Для n=2764 - True
# Для n=2765 - True
# Для n=2766 - True
# Для n=2767 - True
# Для n=2768 - True
# Для n=2769 - True
# Для n=2770 - True
# Для n=2771 - True
# Для n=2772 - True
# Для n=2773 - True
# Для n=2774 - True
# Для n=2775 - True
# Для n=2776 - True
# Для n=2777 - True
# Для n=2778 - True
# Для n=2779 - True
# Для n=2780 - True
# Для n=2781 - True
# Для n=2782 - True
# Для n=2783 - True
# Для n=2784 - True
# Для n=2785 - True
# Для n=2786 - True
# Для n=2787 - True
# Для n=2788 - True
# Для n=2789 - True
# Для n=2790 - True
# Для n=2791 - True
# Для n=2792 - True
# Для n=2793 - True
# Для n=2794 - True
# Для n=2795 - True
# Для n=2796 - True
# Для n=2797 - True
# Для n=2798 - True
# Для n=2799 - True
# Для n=2800 - True
# Для n=2801 - True
# Для n=2802 - True
# Для n=2803 - True
# Для n=2804 - True
# Для n=2805 - True
# Для n=2806 - True
# Для n=2807 - True
# Для n=2808 - True
# Для n=2809 - True
# Для n=2810 - True
# Для n=2811 - True
# Для n=2812 - True
# Для n=2813 - True
# Для n=2814 - True
# Для n=2815 - True
# Для n=2816 - True
# Для n=2817 - True
# Для n=2818 - True
# Для n=2819 - True
# Для n=2820 - True
# Для n=2821 - True
# Для n=2822 - True
# Для n=2823 - True
# Для n=2824 - True
# Для n=2825 - True
# Для n=2826 - True
# Для n=2827 - True
# Для n=2828 - True
# Для n=2829 - True
# Для n=2830 - True
# Для n=2831 - True
# Для n=2832 - True
# Для n=2833 - True
# Для n=2834 - True
# Для n=2835 - True
# Для n=2836 - True
# Для n=2837 - True
# Для n=2838 - True
# Для n=2839 - True
# Для n=2840 - True
# Для n=2841 - True
# Для n=2842 - True
# Для n=2843 - True
# Для n=2844 - True
# Для n=2845 - True
# Для n=2846 - True
# Для n=2847 - True
# Для n=2848 - True
# Для n=2849 - True
# Для n=2850 - True
# Для n=2851 - True
# Для n=2852 - True
# Для n=2853 - True
# Для n=2854 - True
# Для n=2855 - True
# Для n=2856 - True
# Для n=2857 - True
# Для n=2858 - True
# Для n=2859 - True
# Для n=2860 - True
# Для n=2861 - True
# Для n=2862 - True
# Для n=2863 - True
# Для n=2864 - True
# Для n=2865 - True
# Для n=2866 - True
# Для n=2867 - True
# Для n=2868 - True
# Для n=2869 - True
# Для n=2870 - True
# Для n=2871 - True
# Для n=2872 - True
# Для n=2873 - True
# Для n=2874 - True
# Для n=2875 - True
# Для n=2876 - True
# Для n=2877 - True
# Для n=2878 - True
# Для n=2879 - True
# Для n=2880 - True
# Для n=2881 - True
# Для n=2882 - True
# Для n=2883 - True
# Для n=2884 - True
# Для n=2885 - True
# Для n=2886 - True
# Для n=2887 - True
# Для n=2888 - True
# Для n=2889 - True
# Для n=2890 - True
# Для n=2891 - True
# Для n=2892 - True
# Для n=2893 - True
# Для n=2894 - True
# Для n=2895 - True
# Для n=2896 - True
# Для n=2897 - True
# Для n=2898 - True
# Для n=2899 - True
# Для n=2900 - True
# Для n=2901 - True
# Для n=2902 - True
# Для n=2903 - True
# Для n=2904 - True
# Для n=2905 - True
# Для n=2906 - True
# Для n=2907 - True
# Для n=2908 - True
# Для n=2909 - True
# Для n=2910 - True
# Для n=2911 - True
# Для n=2912 - True
# Для n=2913 - True
# Для n=2914 - True
# Для n=2915 - True
# Для n=2916 - True
# Для n=2917 - True
# Для n=2918 - True
# Для n=2919 - True
# Для n=2920 - True
# Для n=2921 - True
# Для n=2922 - True
# Для n=2923 - True
# Для n=2924 - True
# Для n=2925 - True
# Для n=2926 - True
# Для n=2927 - True
# Для n=2928 - True
# Для n=2929 - True
# Для n=2930 - True
# Для n=2931 - True
# Для n=2932 - True
# Для n=2933 - True
# Для n=2934 - True
# Для n=2935 - True
# Для n=2936 - True
# Для n=2937 - True
# Для n=2938 - True
# Для n=2939 - True
# Для n=2940 - True
# Для n=2941 - True
# Для n=2942 - True
# Для n=2943 - True
# Для n=2944 - True
# Для n=2945 - True
# Для n=2946 - True
# Для n=2947 - True
# Для n=2948 - True
# Для n=2949 - True
# Для n=2950 - True
# Для n=2951 - True
# Для n=2952 - True
# Для n=2953 - True
# Для n=2954 - True
# Для n=2955 - True
# Для n=2956 - True
# Для n=2957 - True
# Для n=2958 - True
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-1-a677455a34ab> in <module>
#      13
#      14 while True:
# ---> 15     if first(n) == second(n):
#      16         print(f'Для n={n} - True')
#      17     else:
#
# <ipython-input-1-a677455a34ab> in first(n)
#       3         return n
#       4     elif n > 0:
# ----> 5         return n + first(n-1)
#       6
#       7
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-1-a677455a34ab> in first(n)
#       3         return n
#       4     elif n > 0:
# ----> 5         return n + first(n-1)
#       6
#       7
#
# RecursionError: maximum recursion depth exceeded in comparison
